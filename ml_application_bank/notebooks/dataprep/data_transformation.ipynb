# %% [markdown]
# ## 1. Import packages and read Data

# %%
pip uninstall -y my_krml_ratana
# Out:
# Found existing installation: my_krml_ratana 2025.0.1.2
# Uninstalling my_krml_ratana-2025.0.1.2:
#   Successfully uninstalled my_krml_ratana-2025.0.1.2
# Note: you may need to restart the kernel to use updated packages.

# %%
# %load_ext autoreload
# %autoreload 2

# %%
pip install --index-url https://test.pypi.org/simple/ --no-deps my_krml_ratana
# Out:
# Looking in indexes: https://test.pypi.org/simple/
# ...
#   Using cached https://test-files.pythonhosted.org/packages/a0/3f/ebda5966dda8e9ae45fc25aacb4812d792bb49e7b1e0717a8f3627c52910/my_krml_ratana-2025.0.1.2-py3-none-any.whl.metadata (1.2 kB)
# Using cached https://test-files.pythonhosted.org/packages/a0/3f/ebda5966dda8e9ae45fc25aacb4812d792bb49e7b1e0717a8f3627c52910/my_krml_ratana-2025.0.1.2-py3-none-any.whl (8.2 kB)
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import pandas as pd
import numpy as np

# %%
from my_krml_ratana.data.sets import df_report

# %%
# custom made function
help(df_report)
# Out:
# Help on function df_report in module my_krml_ratana.data.sets:
#
# df_report(df)
#     This gives quick report about the missing values, unique numbers and datatypes.
#     The argument is the DataFram

# %%
df = pd.read_csv("../../data/interim/customers.csv", sep = '|')

# %%
df_trans = pd.read_csv("../../data/interim/merged_output.csv")

# %% [markdown]
# ## 2. Overview of Dataset

# %%
df
# Out:
#              ssn               cc_num     first       last gender  \
# 0    115-04-4507        4218196001337  Jonathan    Johnson      M
# 1    715-55-5575  4351161559407816183    Elaine     Fuller      F
# 2    167-48-5821        4192832764832   Michael    Cameron      M
# 3    406-83-7518     4238849696532874   Brandon   Williams      M
# 4    697-93-1877     4514627048281480      Lisa  Hernandez      F
# ..           ...                  ...       ...        ...    ...
# 995  392-96-7670       30125158904184     Sarah     Martin      F
# 996  594-17-7993      180047909863618      Erin      Wells      F
# 997  196-93-1156        4371450311809   Michael      James      M
# 998  895-65-9304     3519925692476886   Michael      Lewis      M
# 999  107-40-0160      343251790447085     Isaac      Smith      M
#
#                               street              city state    zip      lat  \
# 0               863 Lawrence Valleys            Ambler    PA  19002  40.1809
# ...

# %%
df_report(df)
# Out:
#           %_missing  no_unique  D_types
# ssn             0.0       1000   object
# cc_num          0.0       1000    int64
# first           0.0        367   object
# last            0.0        487   object
# gender          0.0          2   object
# street          0.0       1000   object
# city            0.0        736   object
# state           0.0         51   object
# zip             0.0        954    int64
# lat             0.0        952  float64
# long            0.0        952  float64
# city_pop        0.0        776    int64
# job             0.0        507   object
# dob             0.0        978   object
# acct_num        0.0       1000    int64

# %%
df_trans
# Out:
#                 cc_num      acct_num                         trans_num  \
# 0        4218196001337  888022315787  91ab12e73ef38206e1121e9648d2408d
# 1        4218196001337  888022315787  071553d533a6822a4431c354c434ddcb
# 2        4218196001337  888022315787  0cfad38ef15e4749eff68dc83f62c151
# 3        4218196001337  888022315787  5782693d7c70f062f258cb30bfa8900f
# 4        4218196001337  888022315787  35fd7db657d7e30dd608c37f7798186e
# ...                ...           ...                               ...
# 4260899  4246163034387   21414345345  7432f399b000172fcc1e8790f6fc965b
# 4260900  4246163034387   21414345345  7b6dda3778381981a53b9aa5043fff15
# 4260901  4246163034387   21414345345  a42a8a1fa3919010412c0302912acf67
# 4260902  4246163034387   21414345345  45f5c90dd51fe578857b2c6fa8e55c64
# 4260903  4246163034387   21414345345  6ba78d99dcb30dbb5f3611eee87af76a
#
#           unix_time       category    amt  is_fraud  \
# 0        1558719550  gas_transport  69.12         0
# ...

# %%
df_report(df_trans)
# Out:
#             %_missing  no_unique  D_types
# cc_num            0.0        983    int64
# acct_num          0.0        983    int64
# trans_num         0.0    4260904   object
# unix_time         0.0    4114752    int64
# category          0.0         14   object
# amt               0.0      81218  float64
# is_fraud          0.0          2    int64
# merchant          0.0      21977   object
# merch_lat         0.0    3767589  float64
# merch_long        0.0    4031685  float64

# %%
df_trans.duplicated().sum()
# Out:
# np.int64(0)

# %%
df_trans[df_trans.duplicated() == 'True']
# Out:
# Empty DataFrame
# Columns: [cc_num, acct_num, trans_num, unix_time, category, amt, is_fraud, merchant, merch_lat, merch_long]
# Index: []

# %% [markdown]
# There seems to be no duplicates in the dataset or any missing values.

# %% [markdown]
# ### [2.1] Overview of Customer Dataset

# %%
df.head()
# Out:
#            ssn               cc_num     first       last gender  \
# 0  115-04-4507        4218196001337  Jonathan    Johnson      M
# 1  715-55-5575  4351161559407816183    Elaine     Fuller      F
# 2  167-48-5821        4192832764832   Michael    Cameron      M
# 3  406-83-7518     4238849696532874   Brandon   Williams      M
# 4  697-93-1877     4514627048281480      Lisa  Hernandez      F
#
#                        street        city state    zip      lat     long  \
# 0        863 Lawrence Valleys      Ambler    PA  19002  40.1809 -75.2156
# 1  310 Kendra Common Apt. 164      Leland    NC  28451  34.2680 -78.0578
# 2            05641 Robin Port     Cordova    SC  29039  33.4275 -80.8857
# 3      26916 Carlson Mountain  Birmingham    AL  35242  33.3813 -86.7046
# 4             809 Burns Creek       Fargo    GA  31631  30.7166 -82.5801
#
#    city_pop                                    job         dob      acct_num
# ...

# %%
df.tail()
# Out:
#              ssn            cc_num    first    last gender  \
# 995  392-96-7670    30125158904184    Sarah  Martin      F
# 996  594-17-7993   180047909863618     Erin   Wells      F
# 997  196-93-1156     4371450311809  Michael   James      M
# 998  895-65-9304  3519925692476886  Michael   Lewis      M
# 999  107-40-0160   343251790447085    Isaac   Smith      M
#
#                               street              city state    zip      lat  \
# 995                1666 Jenna Unions            Denver    CO  80236  39.6535
# 996      444 Alexis Estate Suite 824             Wasco    CA  93280  35.6480
# 997  914 Cassandra Gateway Suite 061         Escondido    CA  92026  33.1605
# 998               34141 Katelyn Path          Mattapan    MA   2126  42.2739
# 999        67148 Rose Cliff Apt. 314  Saint Petersburg    FL  33710  27.7898
#
#          long  city_pop                             job         dob  \
# 995 -105.0376    990452             Colour technologist  1993-08-31
# ...

# %%
df.describe()
# Out:
#              cc_num          zip          lat         long      city_pop  \
# count  1.000000e+03   1000.00000  1000.000000  1000.000000  1.000000e+03
# mean   3.656964e+17  51786.20900    37.422795   -92.505277  2.867058e+05
# std    1.227337e+18  29933.13195     5.574397    17.510134  5.329632e+05
# min    6.040027e+10   1571.00000    19.589300  -159.368300  1.050000e+02
# 25%    1.800353e+14  27528.25000    33.712500   -99.159475  2.022950e+04
# 50%    3.517359e+15  49016.00000    38.431750   -87.156600  6.728250e+04
# 75%    4.538733e+15  78599.00000    41.220300   -80.018850  2.499788e+05
# max    4.986227e+18  99705.00000    64.780500   -68.244800  2.906700e+06
#
#            acct_num
# count  1.000000e+03
# mean   4.995849e+11
# std    2.894933e+11
# min    2.348758e+09
# 25%    2.620636e+11
# 50%    4.915295e+11
# 75%    7.571575e+11
# max    9.993899e+11

# %% [markdown]
# + cc_number and acct_num are identifiers
# + zip, lat, long is the postcode latitude and longtitude of the customers address
# + There are no zero or negative city_pop so the data seems to be fairly clean

# %%
#assert that there are no missing values in the dataframe

assert pd.notnull(df).all().all()

# %% [markdown]
#  Hence, it is confirmed that there are no missing values in the dataset.

# %%
# Drop ssn and street as they are redundant

df = df.drop(['ssn','street'], axis = 1)

# %%
df
# Out:
#                   cc_num     first       last gender              city state  \
# 0          4218196001337  Jonathan    Johnson      M            Ambler    PA
# 1    4351161559407816183    Elaine     Fuller      F            Leland    NC
# 2          4192832764832   Michael    Cameron      M           Cordova    SC
# 3       4238849696532874   Brandon   Williams      M        Birmingham    AL
# 4       4514627048281480      Lisa  Hernandez      F             Fargo    GA
# ..                   ...       ...        ...    ...               ...   ...
# 995       30125158904184     Sarah     Martin      F            Denver    CO
# 996      180047909863618      Erin      Wells      F             Wasco    CA
# 997        4371450311809   Michael      James      M         Escondido    CA
# 998     3519925692476886   Michael      Lewis      M          Mattapan    MA
# 999      343251790447085     Isaac      Smith      M  Saint Petersburg    FL
#
#        zip      lat      long  city_pop  \
# ...

# %%
# To build the model First and Last name are unecessary too. We just need the identifiers to merge and create customer's specific model
df = df.drop(['first','last'], axis = 1)

# %%
df
# Out:
#                   cc_num gender              city state    zip      lat  \
# 0          4218196001337      M            Ambler    PA  19002  40.1809
# 1    4351161559407816183      F            Leland    NC  28451  34.2680
# 2          4192832764832      M           Cordova    SC  29039  33.4275
# 3       4238849696532874      M        Birmingham    AL  35242  33.3813
# 4       4514627048281480      F             Fargo    GA  31631  30.7166
# ..                   ...    ...               ...   ...    ...      ...
# 995       30125158904184      F            Denver    CO  80236  39.6535
# 996      180047909863618      F             Wasco    CA  93280  35.6480
# 997        4371450311809      M         Escondido    CA  92026  33.1605
# 998     3519925692476886      M          Mattapan    MA   2126  42.2739
# 999      343251790447085      M  Saint Petersburg    FL  33710  27.7898
#
#          long  city_pop                                    job         dob  \
# ...

# %% [markdown]
# #### [2.1.1] Distribution of gender

# %%
from my_krml_ratana.features.plot import labeled_barplot

# %%
help(labeled_barplot)
# Out:
# Help on function labeled_barplot in module my_krml_ratana.features.plot:
#
# labeled_barplot(data, feature, perc=False, n=None)
#     Creates a barplot with optional percentage labels at the top of the bars.
#
#     Parameters
#     ----------
#     data : pd.DataFrame
#         The dataframe containing the feature.
#     feature : str
#         The column name in the dataframe to plot.
#     perc : bool, optional
#         Whether to display percentages instead of counts (default is False).
#     n : int, optional
#         Number of top categories to display. If None, all categories are displayed (default is None).
#
#     Returns
#     -------
#     None

# %%
labeled_barplot(df, 'gender')
# Out:
# C:\Users\sovan\AppData\Local\pypoetry\Cache\virtualenvs\ml-application-bank-s9wdeFr9-py3.12\Lib\site-packages\my_krml_ratana\features\plot.py:106: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   ax = sns.countplot(

# %% [markdown]
# Male and Female gender seems to be evenly distributed

# %% [markdown]
# #### [2.1.2] Analyze Geo-spatial data

# %%
from my_krml_ratana.features.plot import plot_cities

# %%
help(plot_cities)
# Out:
# Help on function plot_cities in module my_krml_ratana.features.plot:
#
# plot_cities(df, lat, long, city=None, interactive=True)
#     Plots city locations on a map using either static or interactive visualization.
#
#     Parameters:
#     - df (DataFrame): The DataFrame containing city data.
#     - lat (str): Column name for latitude values.
#     - long (str): Column name for longitude values.
#     - city (str or None): Optional column name for city names. Defaults to None.
#     - interactive (bool): If True, generates an interactive map using Folium; otherwise, static         using Matplotlib.
#
#     Returns:
#     - Folium Map (if interactive=True)
#     - Matplotlib plot (if interactive=False)

# %%
plot_cities(df, 'lat', 'long')
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
# ...

# %%
df['state'].value_counts()
# Out:
# state
# CA    107
# TX     87
# NY     63
# FL     59
# PA     45
# MI     43
# IL     39
# NJ     35
# NC     33
# VA     30
# AZ     29
# OH     27
# GA     25
# WA     22
# IN     20
# MO     20
# MA     20
# CO     19
# SC     18
# LA     18
# WI     18
# TN     16
# MD     15
# CT     14
# KY     14
# OR     13
# HI     13
# IA     12
# MN     12
# AR     11
# AL     11
# NM      9
# OK      9
# NE      8
# MS      7
# KS      7
# NV      7
# UT      6
# WV      5
# AK      5
# ME      4
# DE      4
# ID      4
# MT      3
# DC      3
# VT      3
# WY      2
# SD      2
# NH      2
# ND      1
# RI      1
# Name: count, dtype: int64

# %% [markdown]
# Customers seems to be spread out accross the US. Major cities proximity to customers location could be predictive of their monthly spending budgets. In the context of modelling, having only a few sample in each state may lead to overfitting. In our case, we could try to train a specific model just for an individual vs a general model that predicts based on shared features.

# %%
df['zip'].value_counts()
# Out:
# zip
# 7109     3
# 91784    3
# 55014    2
# 19002    2
# 33015    2
#         ..
# 80236    1
# 93280    1
# 92026    1
# 2126     1
# 89183    1
# Name: count, Length: 954, dtype: int64

# %%
df['city'].value_counts()
# Out:
# city
# Brooklyn         13
# Houston           9
# Dallas            9
# Denver            8
# Phoenix           7
#                  ..
# Moreno Valley     1
# Xenia             1
# Brussels          1
# Orangeburg        1
# Cordova           1
# Name: count, Length: 736, dtype: int64

# %%
import seaborn as sns

# %%
sns.histplot(df['city_pop'], kde = True)
# Out:
# <Axes: xlabel='city_pop', ylabel='Count'>

# %% [markdown]
# The city population is skewed to the right, meaning there are fewer major cities that has over 1 million population compared to smaller cities, which make sense.

# %% [markdown]
# #### [2.1.3] Jobs

# %%
df['job'].value_counts()
# Out:
# job
# Computer games developer        7
# Management consultant           6
# Patent attorney                 6
# Engineer, drilling              6
# Designer, exhibition/display    6
#                                ..
# Estate agent                    1
# Engineer, petroleum             1
# Surveyor, mining                1
# Engineer, manufacturing         1
# Colour technologist             1
# Name: count, Length: 507, dtype: int64

# %%
df['job'].nunique()
# Out:
# 507

# %%
df['job'].value_counts()
# Out:
# job
# Computer games developer        7
# Management consultant           6
# Patent attorney                 6
# Engineer, drilling              6
# Designer, exhibition/display    6
#                                ..
# Estate agent                    1
# Engineer, petroleum             1
# Surveyor, mining                1
# Engineer, manufacturing         1
# Colour technologist             1
# Name: count, Length: 507, dtype: int64

# %% [markdown]
# We need to group these jobs into categories because there are too little data points for ML model to learn from.

# %% [markdown]
# #### [2.1.4] Use OpenAI API to categorize these unique jobs into categories

# %%
import os
import openai
from dotenv import load_dotenv

# %%
# Load environment variables from .env files
load_dotenv()
# Out:
# True

# %%
# Set OpenAI API key
openai.api_key = os.getenv("OPENAI_API_KEY")

# %%
def categorize_job(job_title):
    """
    Categorizes a job title into one of 10 predefined broad categories using OpenAI's GPT.

    Parameters:
        job_title (str): The job title to categorize

    Returns: 
        str: The category of the job title
    """
    # Define the 11 predefined categories
    categories = [
        "Technology",
        "Healthcare",
        "Education",
        "Finance",
        "Engineering",
        "Science and Research",
        "Sales and Marketing",
        "Arts and Design",
        "Construction",
        "Administrative Support",
        "Other"
    ]
    
    try:
        # Create a formatted prompt with categories
        prompt = (
            f"Categorize the following job title into one of the following broad categories:\n"
            f"{', '.join(categories)}.\n\n"
            f"Job Title: {job_title}\n\n"
            f"Broad Category:"
        )
        
        # Make API call to OpenAI
        response = openai.Completion.create(
            model="gpt-3.5-turbo-instruct",
            prompt=prompt,
            temperature=0.3,
            max_tokens=10  # Limit response to a short category name
        )
        
        # Extract and clean up response text
        category = response['choices'][0]['text'].strip()
        
        # Ensure the category is valid (fallback to "Other" if invalid)
        if category not in categories:
            category = "Other"
        
        return category
        
    except Exception as e:
        print(f"Error categorizing job: {e}")
        return "Other"

# %% [markdown]
# In the OpenAI API, the temperature parameter controls the randomness or creativity of the model's responses. It determines how "creative" or "focused" the output is by influencing the sampling process when generating text.

# %%
df['job_category'] = df['job'].apply(categorize_job)
# Out:
# Error categorizing job: The server had an error processing your request. Sorry about that! You can retry your request, or contact us through our help center at help.openai.com if you keep seeing this error. (Please include the request ID req_f5fa5b0a081fea4b9617ef8a7cfd3e34 in your email.) {
#   "error": {
#     "message": "The server had an error processing your request. Sorry about that! You can retry your request, or contact us through our help center at help.openai.com if you keep seeing this error. (Please include the request ID req_f5fa5b0a081fea4b9617ef8a7cfd3e34 in your email.)",
#     "type": "server_error",
#     "param": null,
#     "code": null
#   }
# ...

# %%
df
# Out:
#                   cc_num gender              city state    zip      lat  \
# 0          4218196001337      M            Ambler    PA  19002  40.1809
# 1    4351161559407816183      F            Leland    NC  28451  34.2680
# 2          4192832764832      M           Cordova    SC  29039  33.4275
# 3       4238849696532874      M        Birmingham    AL  35242  33.3813
# 4       4514627048281480      F             Fargo    GA  31631  30.7166
# ..                   ...    ...               ...   ...    ...      ...
# 995       30125158904184      F            Denver    CO  80236  39.6535
# 996      180047909863618      F             Wasco    CA  93280  35.6480
# 997        4371450311809      M         Escondido    CA  92026  33.1605
# 998     3519925692476886      M          Mattapan    MA   2126  42.2739
# 999      343251790447085      M  Saint Petersburg    FL  33710  27.7898
#
#          long  city_pop                                    job         dob  \
# ...

# %%
df['job_category'].value_counts()
# Out:
# job_category
# Healthcare                184
# Other                     163
# Arts and Design           151
# Science and Research      113
# Engineering                95
# Finance                    69
# Education                  61
# Sales and Marketing        57
# Technology                 55
# Administrative Support     32
# Construction               20
# Name: count, dtype: int64

# %% [markdown]
# Now there are enough datapoints to use job_category as a feature

# %%
# Drop job and copy the df
df_copy = df.copy().drop(['job'], axis =1)

# %%
df_copy
# Out:
#                   cc_num gender              city state    zip      lat  \
# 0          4218196001337      M            Ambler    PA  19002  40.1809
# 1    4351161559407816183      F            Leland    NC  28451  34.2680
# 2          4192832764832      M           Cordova    SC  29039  33.4275
# 3       4238849696532874      M        Birmingham    AL  35242  33.3813
# 4       4514627048281480      F             Fargo    GA  31631  30.7166
# ..                   ...    ...               ...   ...    ...      ...
# 995       30125158904184      F            Denver    CO  80236  39.6535
# 996      180047909863618      F             Wasco    CA  93280  35.6480
# 997        4371450311809      M         Escondido    CA  92026  33.1605
# 998     3519925692476886      M          Mattapan    MA   2126  42.2739
# 999      343251790447085      M  Saint Petersburg    FL  33710  27.7898
#
#          long  city_pop         dob      acct_num            job_category
# ...

# %% [markdown]
# #### [2.1.5] Covert dob into Age

# %%
from datetime import datetime

# %%
def calculate_age(dob):
    """
    Calculate age from date of birth.

    Parameters:
        dob (str): Date of birth in the format 'YYYY-MM-DD'.

    Returns:
        int: Age in years.
    """
    try:
        # Parse the DOB string into a datetime object
        dob_date = datetime.strptime(dob, "%Y-%m-%d")
        
        # Get today's date
        today = datetime.today() # Can change based on year of dataset
        
        # Calculate age
        age = today.year - dob_date.year - ((today.month, today.day) < (dob_date.month, dob_date.day))
        
        return age
    except ValueError as e:
        print(f"Invalid date format: {e}")
        return None

# %%
df_copy['age'] = df_copy['dob'].apply(calculate_age)

# %%
df_copy
# Out:
#                   cc_num gender              city state    zip      lat  \
# 0          4218196001337      M            Ambler    PA  19002  40.1809
# 1    4351161559407816183      F            Leland    NC  28451  34.2680
# 2          4192832764832      M           Cordova    SC  29039  33.4275
# 3       4238849696532874      M        Birmingham    AL  35242  33.3813
# 4       4514627048281480      F             Fargo    GA  31631  30.7166
# ..                   ...    ...               ...   ...    ...      ...
# 995       30125158904184      F            Denver    CO  80236  39.6535
# 996      180047909863618      F             Wasco    CA  93280  35.6480
# 997        4371450311809      M         Escondido    CA  92026  33.1605
# 998     3519925692476886      M          Mattapan    MA   2126  42.2739
# 999      343251790447085      M  Saint Petersburg    FL  33710  27.7898
#
#          long  city_pop         dob      acct_num            job_category  age
# ...

# %%
# Drop dob
df_copy = df_copy.drop(['dob'], axis = 1)

# %%
df_copy
# Out:
#                   cc_num gender              city state    zip      lat  \
# 0          4218196001337      M            Ambler    PA  19002  40.1809
# 1    4351161559407816183      F            Leland    NC  28451  34.2680
# 2          4192832764832      M           Cordova    SC  29039  33.4275
# 3       4238849696532874      M        Birmingham    AL  35242  33.3813
# 4       4514627048281480      F             Fargo    GA  31631  30.7166
# ..                   ...    ...               ...   ...    ...      ...
# 995       30125158904184      F            Denver    CO  80236  39.6535
# 996      180047909863618      F             Wasco    CA  93280  35.6480
# 997        4371450311809      M         Escondido    CA  92026  33.1605
# 998     3519925692476886      M          Mattapan    MA   2126  42.2739
# 999      343251790447085      M  Saint Petersburg    FL  33710  27.7898
#
#          long  city_pop      acct_num            job_category  age
# ...

# %% [markdown]
# ### [2.3] Overview of Transaction Dataset

# %%
df_trans
# Out:
#                 cc_num      acct_num                         trans_num  \
# 0        4218196001337  888022315787  91ab12e73ef38206e1121e9648d2408d
# 1        4218196001337  888022315787  071553d533a6822a4431c354c434ddcb
# 2        4218196001337  888022315787  0cfad38ef15e4749eff68dc83f62c151
# 3        4218196001337  888022315787  5782693d7c70f062f258cb30bfa8900f
# 4        4218196001337  888022315787  35fd7db657d7e30dd608c37f7798186e
# ...                ...           ...                               ...
# 4260899  4246163034387   21414345345  7432f399b000172fcc1e8790f6fc965b
# 4260900  4246163034387   21414345345  7b6dda3778381981a53b9aa5043fff15
# 4260901  4246163034387   21414345345  a42a8a1fa3919010412c0302912acf67
# 4260902  4246163034387   21414345345  45f5c90dd51fe578857b2c6fa8e55c64
# 4260903  4246163034387   21414345345  6ba78d99dcb30dbb5f3611eee87af76a
#
#           unix_time       category    amt  is_fraud  \
# 0        1558719550  gas_transport  69.12         0
# ...

# %%
df_report(df_trans)
# Out:
#             %_missing  no_unique  D_types
# cc_num            0.0        983    int64
# acct_num          0.0        983    int64
# trans_num         0.0    4260904   object
# unix_time         0.0    4114752    int64
# category          0.0         14   object
# amt               0.0      81218  float64
# is_fraud          0.0          2    int64
# merchant          0.0      21977   object
# merch_lat         0.0    3767589  float64
# merch_long        0.0    4031685  float64

# %%
# Explore category
df_trans['category'].value_counts()
# Out:
# category
# shopping_pos      420268
# home              403237
# grocery_pos       401000
# kids_pets         372055
# gas_transport     365233
# food_dining       320989
# entertainment     312478
# shopping_net      307013
# personal_care     300730
# misc_pos          281977
# health_fitness    265986
# misc_net          191290
# grocery_net       181614
# travel            137034
# Name: count, dtype: int64

# %% [markdown]
# There are many data points for each category which is good for training model

# %%
# Explore merchant
df_trans['merchant'].value_counts()
# Out:
# merchant
# Smith PLC                    5737
# Johnson LLC                  5713
# Smith and Sons               5642
# Smith Inc                    5456
# Johnson Inc                  5243
#                              ...
# Santiago-Smith                 47
# Ray, Michael and Anderson      44
# Graham, Cross and Miller       44
# Jackson, King and Smith        44
# Peterson-Adams                 43
# Name: count, Length: 21977, dtype: int64

# %%
df_trans['merchant'].value_counts().head(50)
# Out:
# merchant
# Smith PLC            5737
# Johnson LLC          5713
# Smith and Sons       5642
# Smith Inc            5456
# Johnson Inc          5243
# Smith Group          5126
# Johnson PLC          4941
# Williams Inc         4883
# Smith Ltd            4836
# Smith LLC            4785
# Williams and Sons    4327
# Johnson Group        4269
# Williams LLC         3708
# Jones PLC            3652
# Jones LLC            3543
# Brown PLC            3483
# Brown Inc            3481
# Miller Inc           3315
# Williams Group       3279
# Johnson Ltd          3148
# Johnson and Sons     3122
# Miller Group         3083
# Williams PLC         3062
# Brown LLC            3038
# Davis LLC            3034
# Jones Inc            3032
# Garcia PLC           2977
# Miller and Sons      2940
# Rodriguez LLC        2930
# Jones Ltd            2903
# Miller LLC           2902
# Moore Inc            2822
# Jones and Sons       2711
# Brown Group          2685
# Wilson LLC           2514
# ...

# %%
df_trans['merchant'].nunique()
# Out:
# 21977

# %%
df_trans['merchant'].value_counts().tail(50)
# Out:
# merchant
# Robertson, Horton and Smith      54
# Burns-James                      54
# Hernandez-Carr                   54
# Kemp PLC                         54
# Sanchez-Ibarra                   53
# Terry, Davis and Gillespie       53
# Palmer-Mitchell                  53
# Sanchez-Cross                    53
# Bishop, Gibson and Mckee         53
# Cardenas Ltd                     53
# Shannon-Mills                    53
# Cruz, Blair and Estes            53
# Rogers, Knight and Ferguson      53
# Cross-Chen                       53
# Bartlett-Montgomery              53
# Figueroa, Gross and Olson        53
# Murray, Johnson and Hall         52
# Atkins and Sons                  52
# Walker-Hill                      52
# Miller-Alvarado                  52
# Dixon-Williams                   52
# Mcfarland, Hatfield and Gates    52
# Sullivan, Thompson and Sims      52
# Berry-Jackson                    52
# Hughes-Mckay                     52
# Hanna-King                       52
# ...

# %% [markdown]
# These merchant names are perhaps synthetic based on the names shown. We can later compare it to merchant lat and long

# %% [markdown]
# #### [2.3.1] Convert UNIX time to date and time

# %%
df_trans['timestamp'] = pd.to_datetime(df_trans['unix_time'], unit= 's')

# %%
# Drop unix_time
df_trans = df_trans.drop(['unix_time'], axis = 1)

# %%
df_trans
# Out:
#                 cc_num      acct_num                         trans_num  \
# 0        4218196001337  888022315787  91ab12e73ef38206e1121e9648d2408d
# 1        4218196001337  888022315787  071553d533a6822a4431c354c434ddcb
# 2        4218196001337  888022315787  0cfad38ef15e4749eff68dc83f62c151
# 3        4218196001337  888022315787  5782693d7c70f062f258cb30bfa8900f
# 4        4218196001337  888022315787  35fd7db657d7e30dd608c37f7798186e
# ...                ...           ...                               ...
# 4260899  4246163034387   21414345345  7432f399b000172fcc1e8790f6fc965b
# 4260900  4246163034387   21414345345  7b6dda3778381981a53b9aa5043fff15
# 4260901  4246163034387   21414345345  a42a8a1fa3919010412c0302912acf67
# 4260902  4246163034387   21414345345  45f5c90dd51fe578857b2c6fa8e55c64
# 4260903  4246163034387   21414345345  6ba78d99dcb30dbb5f3611eee87af76a
#
#               category    amt  is_fraud                            merchant  \
# ...

# %% [markdown]
# ## 3. Merge transactions and customer data

# %%
df_copy
# Out:
#                   cc_num gender              city state    zip      lat  \
# 0          4218196001337      M            Ambler    PA  19002  40.1809
# 1    4351161559407816183      F            Leland    NC  28451  34.2680
# 2          4192832764832      M           Cordova    SC  29039  33.4275
# 3       4238849696532874      M        Birmingham    AL  35242  33.3813
# 4       4514627048281480      F             Fargo    GA  31631  30.7166
# ..                   ...    ...               ...   ...    ...      ...
# 995       30125158904184      F            Denver    CO  80236  39.6535
# 996      180047909863618      F             Wasco    CA  93280  35.6480
# 997        4371450311809      M         Escondido    CA  92026  33.1605
# 998     3519925692476886      M          Mattapan    MA   2126  42.2739
# 999      343251790447085      M  Saint Petersburg    FL  33710  27.7898
#
#          long  city_pop      acct_num            job_category  age
# ...

# %%
df_trans
# Out:
#                 cc_num      acct_num                         trans_num  \
# 0        4218196001337  888022315787  91ab12e73ef38206e1121e9648d2408d
# 1        4218196001337  888022315787  071553d533a6822a4431c354c434ddcb
# 2        4218196001337  888022315787  0cfad38ef15e4749eff68dc83f62c151
# 3        4218196001337  888022315787  5782693d7c70f062f258cb30bfa8900f
# 4        4218196001337  888022315787  35fd7db657d7e30dd608c37f7798186e
# ...                ...           ...                               ...
# 4260899  4246163034387   21414345345  7432f399b000172fcc1e8790f6fc965b
# 4260900  4246163034387   21414345345  7b6dda3778381981a53b9aa5043fff15
# 4260901  4246163034387   21414345345  a42a8a1fa3919010412c0302912acf67
# 4260902  4246163034387   21414345345  45f5c90dd51fe578857b2c6fa8e55c64
# 4260903  4246163034387   21414345345  6ba78d99dcb30dbb5f3611eee87af76a
#
#               category    amt  is_fraud                            merchant  \
# ...

# %%
df_master = pd.merge(df_copy, df_trans, on = ["cc_num", "acct_num"], how = "inner")

# %%
df_master
# Out:
#                   cc_num gender              city state    zip      lat  \
# 0          4218196001337      M            Ambler    PA  19002  40.1809
# 1          4218196001337      M            Ambler    PA  19002  40.1809
# 2          4218196001337      M            Ambler    PA  19002  40.1809
# 3          4218196001337      M            Ambler    PA  19002  40.1809
# 4          4218196001337      M            Ambler    PA  19002  40.1809
# ...                  ...    ...               ...   ...    ...      ...
# 4260899  343251790447085      M  Saint Petersburg    FL  33710  27.7898
# 4260900  343251790447085      M  Saint Petersburg    FL  33710  27.7898
# 4260901  343251790447085      M  Saint Petersburg    FL  33710  27.7898
# 4260902  343251790447085      M  Saint Petersburg    FL  33710  27.7898
# 4260903  343251790447085      M  Saint Petersburg    FL  33710  27.7898
#
#             long  city_pop      acct_num job_category  age  \
# ...

# %%
df_master.columns
# Out:
# Index(['cc_num', 'gender', 'city', 'state', 'zip', 'lat', 'long', 'city_pop',
#        'acct_num', 'job_category', 'age', 'trans_num', 'category', 'amt',
#        'is_fraud', 'merchant', 'merch_lat', 'merch_long', 'timestamp'],
#       dtype='object')

# %%
# Save set to interim folder
df_master.to_csv('../../data/interim/df_master.csv', index = False)
